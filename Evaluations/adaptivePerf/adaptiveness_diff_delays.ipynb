# %%
file1 = '2024_Oct_20_0856_latency_k8s.csv'
file2 = '2024_Oct_20_0901_latency_NetMARKS.csv'
file3 = '2024_Oct_20_0904_latency_TraDE.csv'

# %%
'''(1) plot Response Time for namesapce of social-network ''' # default k8s scheduling method
from os import times
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file

# df = pd.read_csv('data/{timestamp}_latency_k8s.csv')
df = pd.read_csv(file1)
# Convert the 'metric' column dictionaries to strings
df['metric'] = df['metric'].apply(lambda x: str(eval(x)))
# Convert the 'timestamp' column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])
# Calculate the elapsed time in seconds from the start of data collection
df['elapsed_time'] = (df['timestamp'] - df['timestamp'].min()).dt.total_seconds()
# Plot the data
if not df.empty:
    plt.figure(figsize=(10, 3))
    
    for key, grp in df.groupby(['metric']):
        plt.plot(grp['elapsed_time'], grp['value'], label=key)
    
    #set font size for x and y axis
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.ylim(0, 800)

    plt.xlabel('Time (seconds)',fontsize=12)
    plt.ylabel('Response Time (ms)', fontsize=12)   
    # plt.title('K8s Average Response Time for Composepost Request from Istio Metrics')
    plt.grid(True)
    # plt.xticks(rotation=45)
    plt.tight_layout()
    # plt.savefig('prometheus_data_plot.png')  # Save plot as a PNG file
    plt.show()  # Display the plot

# print("Plot has been saved to prometheus_data_plot.png")

# %%
'''(2) plot Response Time for namesapce of social-network2 ''' # NetMARKS scheduling method
# from turtle import color
# from tkinter import font
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv(file2)

# Convert the 'metric' column dictionaries to strings
df['metric'] = df['metric'].apply(lambda x: str(eval(x)))
# Convert the 'timestamp' column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])
# Calculate the elapsed time in seconds from the start of data collection
df['elapsed_time'] = (df['timestamp'] - df['timestamp'].min()).dt.total_seconds()
# Plot the data
if not df.empty:
    plt.figure(figsize=(9, 3))
    
    for key, grp in df.groupby(['metric']):
        plt.plot(grp['elapsed_time'], grp['value'], label=key, color='red')

    
    #set font size for x and y axis
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.ylim(0, 800)
    
    #set plot line color as red
    # plt.plot(grp['elapsed_time'], grp['value'], label=key, color='red')
    

    plt.xlabel('Time (seconds)', fontsize=12)
    plt.ylabel('Response Time (ms)', fontsize=12)
    # plt.title('NetMARKS Average Response Time for Composepost Request from Istio Metrics')
    plt.grid(True)
    # plt.xticks(rotation=45)
    plt.tight_layout()
    # plt.savefig('prometheus_data_plot.png')  # Save plot as a PNG file
    plt.show()  # Display the plot

# print("Plot has been saved to prometheus_data_plot.png")

# %%
'''(3) plot Response Time for namesapce of social-network2 ''' # TraDE scheduling method
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv(file3)

# Convert the 'metric' column dictionaries to strings
df['metric'] = df['metric'].apply(lambda x: str(eval(x)))
# Convert the 'timestamp' column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])
# Calculate the elapsed time in seconds from the start of data collection
df['elapsed_time'] = (df['timestamp'] - df['timestamp'].min()).dt.total_seconds()
# Plot the data
if not df.empty:
    plt.figure(figsize=(9, 3))
    
    for key, grp in df.groupby(['metric']):
        plt.plot(grp['elapsed_time'], grp['value'], label=key)

    #set font size for x and y axis
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.ylim(0, 800)

    plt.xlabel('Time (seconds)', fontsize=12)
    plt.ylabel('Response Time (ms)', fontsize=12)
    # plt.title('TraDE Average Response Time for Composepost Request from Istio Metrics')
    plt.grid(True)
    # plt.xticks(rotation=45)
    plt.tight_layout()
    # plt.savefig('prometheus_data_plot.png')  # Save plot as a PNG file
    plt.show()  # Display the plot

# print("Plot has been saved to prometheus_data_plot.png")
